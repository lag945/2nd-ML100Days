# %% [markdown]
# # 作業1：
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 1. 你選的這組資料為何重要
# 我選擇的是世界人口的資料集 https://www.kaggle.com/centurion1986/world-population
# 包含了各國各年的人口總數
# 對於我想預測人口成長議題很有幫助
# 至於為何想預測單純是我感興趣
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# 直接在Kaggle搜尋出來的，提供者是Alexander Shakhov
# 他並沒有對資料說明，但是我知道wiki也有這些資訊只是沒有整理成一個分析的csv檔而已
# 若有疑義可以跟wiki資料比對
#
# 3. 蒐集而來的資料型態為何
# .csv
#
# 4. 這組資料想解決的問題如何評估
# 這筆資料其實只有我想預測的結果; 國家與年代對我的預測基本上都不是很重要的參數

# %% [markdown]
# # 作業2：
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 我假設自由載客車隊是白牌車車隊，在台灣感覺像違法的，但我在桃園常坐，所以有些心得。
# 提升業績就是要提升載客數，白牌車隊基本上都是被叫車，跟Uber有點像。
# 所以如何增加新客戶，保留舊客戶就為其提升業績的主要方式
# 為何我在桃園會坐白牌車而高雄不會坐？因為高雄沒有了解的管道。
# 桃園是朋友提供資訊，而且去的地點跟一般小黃計程車差了好幾百，所以選擇了白牌車。
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 所以我覺得搜集乘客發現白牌車的管道，在適合的管道上加大廣告力道。
# 至於資料由於大家都是同車隊，也都想要賺更多錢，所以可以請司機蒐集。
#
# 3. 蒐集而來的資料型態為何
# 叫車一定會有手機，所以其實資料不太會重複，再配合管道，
# 內建幾個分類與其他，資料就成形了，建議先放在資料庫中，之後依需求輸出成csv
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 蒐集完後分析，根據商業機制，也許是針對次數多的管道加大力道，也許是針對次數少的管道加大力道，
# 找出更多類似客源或開拓出更多新的客源。

# %% [markdown]
# # 作業3

# %% [markdown]
# # 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np #NumPy是Python語言的一個擴充程式庫。支援高階大量的維度陣列與矩陣運算，此外也針對陣列運算提供大量的數學函式函式庫。
import matplotlib.pyplot as plt #matplotlib 是Python程式語言及其數值數學擴展包 NumPy的可視化操作界面。
#pyplot是matplotlib的一個模塊，它提供了一個類似MATLAB的接口。

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
def mean_squared_error(y, yp):
    """
    計算 MSE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mse: MSE
    """
    mse = MSE = sum((y - yp)**2) / len(y)
    return mse

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101) #0-100間均分成101個值

y = (x_lin + np.random.randn(101) * 5) * w + b #與0-1間*5的亂數相加再*w+b

# 把x_lin當x軸,y當y軸畫出藍點
plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b #把亂數拿掉當作預估值
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction') #把預估值當y軸畫出紅線
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 262.345
# The Mean absolute error is 12.381
